# %%
# suppress annoying pandas warnings
from contextlib import contextmanager
import logging
import warnings

import pandas as pd

warnings.simplefilter('ignore')

logging.basicConfig()
logger = logging.getLogger()

@contextmanager
def debug_log():
    logger.setLevel(logging.DEBUG)
    yield
    logger.setLevel(logging.WARNING)

# %%
DRAFT_YEARS = [2014, 2015, 2016, 2017, 2018]
DRAFT_URL = "https://www.basketball-reference.com/draft/NBA_{year}.html"


def draft_for_year(year):
    url = DRAFT_URL.format(year=year)
    logging.debug("Getting data for {0}".format(url))
    return pd.read_html(url, header=1, skiprows=[32, 33])[0]


def get_draft_data():
    
    frames = []
    for year in DRAFT_YEARS:
        draft_data = draft_for_year(year)
        draft_data['Draft_Year'] = year
        frames.append(draft_data)
    
    return pd.concat(frames)

# %%
PLAYER_YEARS = [y + 1 for y in DRAFT_YEARS]
PLAYER_URL = "https://www.basketball-reference.com/leagues/NBA_{year}_per_game.html"

# Fix inconcistencies between players and drafted players listings
MANUAL_PLAYER_MAPPINGS = {
    'Timothe Luwawu-Cabarrot': 'Timothe Luwawu',
    'Taurean Waller-Prince': 'Taurean Prince',
    "DeAndre' Bembry": 'DeAndre Bembry',
    "Johnny O'Bryant": "Johnny O'Bryant III",
    "Glenn Robinson": "Glenn Robinson III",
    "Devyn Marble": "Roy Devyn Marble",
    "Larry Nance": "Larry Nance Jr.",
    "Joe Young": "Joseph Young",
    'Walter Tavares': "Edy Tavares"
}

def player_data_for_year(year):
    url = PLAYER_URL.format(year=year)
    logging.debug("Getting data for {0}".format(url))
    data = pd.read_html(url)[0]
    
    # 1) remove header rows
    data = data[data.Rk != 'Rk']
    
    # 2) cast to the correct type
    non_numeric_cols = set(['Player', 'Pos', 'Tm'])
    for col in data.columns:
        if col in non_numeric_cols:
            continue
        data.loc[:, col] = pd.to_numeric(data[col], errors='downcast')  
    return data


def get_player_raw_data():
    frames = []
    for year in PLAYER_YEARS:
        player_data = player_data_for_year(year)
        player_data['Year'] = year
        frames.append(player_data)
    
    data = pd.concat(frames)
    
    # fix inconsistent naming between draft and player listings
    data['Player'] = data['Player'].apply(lambda pn: MANUAL_PLAYER_MAPPINGS.get(pn, pn))
    return data


def min_year_and_max_games_played_for_team(data):
    
    players_by_min_years = data[['Player', 'Year']].groupby('Player').min().reset_index()
    players_min_years_only = pd.merge(data, players_by_min_years, on=['Player', 'Year'], how='inner')
    
    # find the team which the player played the most games for
    no_tm = players_min_years_only[players_min_years_only.Tm != 'TOT']
    player_groupby = no_tm.groupby(by='Player')
    players_single_team = player_groupby[['G', 'Tm', 'Year']].max().reset_index()
    return players_single_team

# %%
def merge_draft_year_with_player_data(draft_data, player_data):
    
    # remove unwanted columns before the merge
    draft_data.drop(columns=['Tm', 'Rk'], inplace=True)
    player_data.drop(columns=['G'], inplace=True)
    
    return pd.merge(player_data, draft_data, how='inner', on='Player')

# %%
with debug_log():
    draft_data = get_draft_data()
    player_raw_data = get_player_raw_data()
    players_by_min_year_max_games = min_year_and_max_games_played_for_team(player_raw_data)
    
    merged = merge_draft_year_with_player_data(draft_data, players_by_min_year_max_games)
    merged['WS/Year'] = merged['WS'] / merged['Yrs']
# Out:
# DEBUG:root:Getting data for https://www.basketball-reference.com/draft/NBA_2014.html
# DEBUG:root:Getting data for https://www.basketball-reference.com/draft/NBA_2015.html
# DEBUG:root:Getting data for https://www.basketball-reference.com/draft/NBA_2016.html
# DEBUG:root:Getting data for https://www.basketball-reference.com/draft/NBA_2017.html
# DEBUG:root:Getting data for https://www.basketball-reference.com/draft/NBA_2018.html
# DEBUG:root:Getting data for https://www.basketball-reference.com/leagues/NBA_2015_per_game.html
# DEBUG:root:Getting data for https://www.basketball-reference.com/leagues/NBA_2016_per_game.html
# DEBUG:root:Getting data for https://www.basketball-reference.com/leagues/NBA_2017_per_game.html
# DEBUG:root:Getting data for https://www.basketball-reference.com/leagues/NBA_2018_per_game.html
# DEBUG:root:Getting data for https://www.basketball-reference.com/leagues/NBA_2019_per_game.html

# %%
# import matplotlib.pyplot as plt
# %matplotlib inline


# merged.plot(kind='scatter', x='Pk', y='VORP', figsize=(12, 5))

# %%
draft_data.columns
# Out:
# Index(['Pk', 'Player', 'College', 'Yrs', 'G', 'MP', 'PTS', 'TRB', 'AST', 'FG%',
#        '3P%', 'FT%', 'MP.1', 'PTS.1', 'TRB.1', 'AST.1', 'WS', 'WS/48', 'BPM',
#        'VORP', 'Draft_Year'],
#       dtype='object')

# %%
merged[merged.Tm == 'DEN'].sort_values(by='Pk')
# Out:
#                 Player   Tm  Year  Pk                                College  \
# 75     Emmanuel Mudiay  DEN  2016   7                                    NaN
# 105       Jamal Murray  DEN  2017   7                 University of Kentucky
# 138   Juan Hernangomez  DEN  2017  15                                    NaN
# 145       Jusuf Nurkic  DEN  2015  16                                    NaN
# 81         Gary Harris  DEN  2015  19              Michigan State University
# 170      Malik Beasley  DEN  2017  19               Florida State University
# 243        Tyler Lydon  DEN  2018  24                    Syracuse University
# 111  Jarred Vanderbilt  DEN  2019  41                 University of Kentucky
# 193       Nikola Jokic  DEN  2016  41                                    NaN
# 187       Monte Morris  DEN  2018  51                  Iowa State University
# 234       Thomas Welsh  DEN  2019  58  University of California, Los Angeles
#
#      Yrs      G      MP     PTS     TRB  ...  MP.1  PTS.1  TRB.1  AST.1    WS  \
# 75   4.0  226.0  5755.0  2602.0   682.0  ...  25.5   11.5    3.0    4.2  -1.1
# 105  3.0  214.0  6036.0  3094.0   727.0  ...  28.2   14.5    3.4    3.3   9.7
# 138  3.0  141.0  2336.0   780.0   485.0  ...  16.6    5.5    3.4    0.6   5.1
# 145  5.0  294.0  6658.0  3324.0  2303.0  ...  22.6   11.3    7.8    1.8  14.4
# 81   5.0  287.0  8200.0  3614.0   735.0  ...  28.6   12.6    2.6    2.2  15.1
# 170  3.0  141.0  2119.0   961.0   231.0  ...  15.0    6.8    1.6    0.8   4.4
# 243  2.0   22.0    89.0    21.0    16.0  ...   4.0    1.0    0.7    0.2   0.1
# 111  1.0    3.0    14.0     1.0    11.0  ...   4.7    0.3    3.7    0.3   0.0
# 193  4.0  284.0  7981.0  4544.0  2676.0  ...  28.1   16.0    9.4    5.1  35.8
# 187  2.0   60.0  1449.0   626.0   153.0  ...  24.2   10.4    2.6    3.8   4.9
# 234  1.0    9.0    33.0    14.0     4.0  ...   3.7    1.6    0.4    0.4   0.1
#
#      WS/48  BPM  VORP  Draft_Year   WS/Year
# 75  -0.009 -3.8  -2.6        2015 -0.275000
# 105  0.077 -1.1   1.3        2016  3.233333
# 138  0.106 -1.0   0.6        2016  1.700000
# 145  0.104  1.0   5.1        2014  2.880000
# 81   0.089  0.1   4.3        2014  3.020000
# 170  0.100 -1.6   0.2        2016  1.466667
# 243  0.065 -3.2   0.0        2017  0.050000
# 111 -0.049 -5.9   0.0        2018  0.000000
# 193  0.215  7.5  19.1        2014  8.950000
# 187  0.161  0.5   0.9        2017  2.450000
# 234  0.134 -3.1   0.0        2018  0.100000
#
# [11 rows x 24 columns]

# %%
merged['WS/Year'] = merged['WS'] / merged['Yrs']
merged.to_csv("/Users/jimmyzhang/Documents/draft_analysis.csv", index=False)

# %%
# ==== utility functions for cleaning ====


def get_unmerged_draft_players(draft_data, merged):
    return draft_data[(~draft_data.Player.isin(merged.Player))][['Player', 'G', 'Draft_Year']].dropna()

get_unmerged_draft_players(draft_data, merged)
# Out:
#             Player     G  Draft_Year
# 42  Walter Tavares  13.0        2014

# %%
player_advanced_2019 = player_data_for_year()

# %%
def advanced_player_data_for_year():
    url = 'https://www.basketball-reference.com/leagues/NBA_2019_advanced.html'
    logging.debug("Getting data for {0}".format(url))
    data = pd.read_html(url)[0]
    
    # 1) remove header rows
    data = data[data.Rk != 'Rk']
    
    # 2) cast to the correct type
    non_numeric_cols = set(['Player', 'Pos', 'Tm'])
    for col in data.columns:
        if col in non_numeric_cols:
            continue
        data.loc[:, col] = pd.to_numeric(data[col], errors='downcast')
    
    return data.drop(columns=['Unnamed: 19', 'Unnamed: 24'])
        
#     # take only the total stat
#     no_tm = data[data.Tm != 'TOT']
#     player_groupby = data.groupby(by='Player')
#     return players_single_team.drop()
    
adv_data = advanced_player_data_for_year()

# %%
den_pks = set(merged[merged['Tm'] == 'DEN'].Pk.values)
ph_pks = set(merged[merged['Tm'] == 'PHO'].Pk.values)



merged[merged.apply(lambda x: x.Pk in den_pks or x.Pk in ph_pks, axis=1)]
# Out:
#                      Player   Tm  Year  Pk  \
# 0              A.J. Hammons  DAL  2017  46
# 1              Aaron Gordon  ORL  2015   4
# 3               Abdel Nader  BOS  2018  58
# 4             Adreian Payne  MIN  2015  15
# 5               Alec Peters  PHO  2018  54
# 8            Andrew Wiggins  MIN  2015   1
# 9           Anfernee Simons  POR  2019  24
# 11            Anthony Brown  LAL  2016  34
# 12              Bam Adebayo  MIA  2018  14
# 13               Ben Bentil  DAL  2017  51
# 14              Ben Simmons  PHI  2018   1
# 26            Cameron Payne  OKC  2016  14
# 28               Cedi Osman  CLE  2018  31
# 34         Cleanthony Early  NYK  2015  34
# 36            Collin Sexton  CLE  2019   8
# 42            Damien Inglis  MIL  2016  31
# 48               Davon Reed  PHO  2018  32
# 50        De'Anthony Melton  PHO  2019  46
# 52            Deandre Ayton  PHO  2019   1
# 55        Demetrius Jackson  BOS  2017  45
# 57         Denzel Valentine  CHI  2017  14
# 59             Devin Booker  PHO  2016  13
# 60          Devonte' Graham  CHO  2019  34
# 228  1078.0  ...  27.7   14.4    4.1    1.1  13.1  0.087  -1.2   1.4
# 231   904.0  ...  19.9    7.6    3.6    2.3   9.6  0.093  -0.3   2.2
# 232     1.0  ...   3.0    3.0    0.5    0.0   0.0  0.291  -4.1   0.0
# 234     4.0  ...   3.7    1.6    0.4    0.4   0.1  0.134  -3.1   0.0
# 235   443.0  ...  13.3    4.5    2.6    0.5   3.9  0.083  -2.1  -0.1
# 236   253.0  ...  15.0    5.5    1.7    0.9   1.5  0.033  -4.7  -1.5
# 240    39.0  ...   7.2    2.4    1.3    0.9   0.2  0.038  -5.0  -0.2
# 241   175.0  ...  14.7    6.0    2.1    1.2   0.4  0.017  -4.6  -0.8
# 242   250.0  ...  12.6    4.2    1.3    1.9   1.3  0.026  -4.6  -1.5
# 243    16.0  ...   4.0    1.0    0.7    0.2   0.1  0.065  -3.2   0.0
# 244   223.0  ...  20.9    7.5    1.7    4.0   0.5  0.008  -4.7  -1.9
# 246   318.0  ...  16.6    4.6    1.4    3.0   6.9  0.090  -1.2   0.7
# 249   307.0  ...  25.2   10.3    7.0    1.8   2.0  0.084  -0.3   0.5
# 253   466.0  ...  16.9    5.5    3.8    0.9   3.0  0.069  -1.5   0.3
# 254   925.0  ...  29.7   15.6    3.3    3.4   7.4  0.043  -1.7   0.6
#
#      Draft_Year   WS/Year
# 0          2016  0.000000
# 1          2014  3.280000
# 3          2016  0.200000
# 4          2014 -0.150000
# 5          2017  0.300000
# 8          2014  2.580000
# 9          2018 -0.400000
# 11         2015 -0.066667
# 12         2017  4.100000
# 13         2016 -0.100000
# 14         2016  7.650000
# 26         2015  0.575000
# 28         2015  0.700000
# 34         2014 -0.300000
# 36         2018 -1.500000
# 42         2014 -0.100000
# 48         2017 -0.150000
# 50         2018 -0.200000
# 52         2018  4.600000
# 55         2016  0.066667
# 57         2016  1.550000
# 59         2015  2.050000
# 60         2018  0.400000
# 61         2016  1.600000
# 63         2017  0.600000
# 65         2017  3.800000
# 68         2016 -0.100000
# 70         2014  3.780000
# 73         2014  2.440000
# 74         2018 -0.600000
# ..          ...       ...
# 178        2016  0.866667
# 182        2018  2.000000
# 187        2017  2.450000
# 188        2015  4.250000
# 192        2014  0.680000
# 193        2014  8.950000
# 195        2015  1.650000
# 200        2015  1.150000
# 214        2015  1.325000
# 217        2014  1.260000
# 219        2018  0.400000
# 223        2015  0.850000
# 224        2016  0.000000
# 225        2017  1.150000
# 227        2017  0.800000
# 228        2014  2.620000
# 231        2015  2.400000
# 232        2014  0.000000
# 234        2018  0.100000
# 235        2016  1.300000
# 236        2016  0.500000
# 240        2018  0.200000
# 241        2017  0.200000
# 242        2014  0.325000
# 243        2017  0.050000
# 244        2016  0.166667
# 246        2015  1.725000
# 249        2018  2.000000
# 253        2017  1.500000
# 254        2014  1.480000
#
# [99 rows x 24 columns]

# %%
drop_columns = ['PTS', 'G', 'MP', 'TRB', 'AST', 
                'FG%','3P%', 'FT%', 'MP.1', 'PTS.1', 'TRB.1', 'AST.1', 
                'WS', 'WS/48', 'BPM', 'VORP', 'Year', 'WS/Year']

copy = merged.drop(columns=drop_columns)
copy.rename(columns={'Tm': 'Draft Team'}, inplace=True)
merged_2019 = pd.merge(copy, adv_data, how='inner', on="Player")

# %%
merged_2019[merged_2019.MP > 500].sort_values(by='PER', ascending=False)
# Out:
#                   Player Draft Team  Pk  \
# 177         Nikola Jokic        DEN  41
# 134   Karl-Anthony Towns        MIN   1
# 111          Joel Embiid        PHI   3
# 30          Clint Capela        HOU  25
# 171     Montrezl Harrell        HOU  32
# 132         Jusuf Nurkic        DEN  16
# 56      Domantas Sabonis        OKC  11
# 188       Richaun Holmes        PHI  37
# 123        Julius Randle        LAL   7
# 112         John Collins        ATL  19
# 218        Thomas Bryant        LAL  42
# 168    Mitchell Robinson        NYK  36
# 44         Deandre Ayton        PHO   1
# 239    Willy Hernangomez        NYK  35
# 12           Ben Simmons        PHI   1
# 93         Jahlil Okafor        PHI   3
# 87           Ivica Zubac        LAL  32
# 62         Dwight Powell        DAL  45
# 152          Luka Doncic        DAL   3
# 86           Ivica Zubac        LAL  32
# 32      D'Angelo Russell        LAL   2
# 173         Myles Turner        IND  11
# 102        Jarrett Allen        BRK  22
# 53          Devin Booker        PHO  13
# 95          Jakob Poeltl        TOR   9
# 182        Pascal Siakam        TOR  27
# 241          Zach LaVine        MIN  13
# 238  Willie Cauley-Stein        SAC   6
# 42          De'Aaron Fox        SAC   5
# 13          Bobby Portis        CHI  22
# ..                   ...        ...  ..
# 96         Jalen Brunson        DAL  33
# 210       Sterling Brown        MIL  46
# 79        Hamidou Diallo        OKC  45
# 153         Luke Kennard        DET  12
# 33           D.J. Wilson        MIL  17
# 23         Cameron Payne        OKC  14
# 59        Doug McDermott        CHI  11
# 31         Collin Sexton        CLE   8
# 174         Nik Stauskas        SAC   8
# 125       Justin Jackson        SAC  15
# 128       Justin Jackson        SAC  43
# 129       Justin Jackson        SAC  43
# 126       Justin Jackson        SAC  15
# 107         Jerian Grant        NYK  19
# 208      Stanley Johnson        DET   8
# 139        Kevin Huerter        ATL  19
# 118            Josh Hart        LAL  30
# 159        Mario Hezonja        ORL   5
# 43     De'Anthony Melton        PHO  46
# 207      Stanley Johnson        DET   8
# 180           OG Anunoby        TOR  23
# 237        Wesley Iwundu        ORL  33
# 27    Chandler Hutchison        CHI  22
# 68         Frank Jackson        NOP  31
# 120          Josh Okogie        MIN  20
# 140           Kevin Knox        NYK   9
# 66            Elie Okobo        PHO  31
# 216    Terrance Ferguson        OKC  21
# 18           Bruce Brown        DET  42
# 71       Frank Ntilikina        NYK   8
#
#                                    College  Yrs  Draft_Year   Rk Pos  Age  \
# 177                                    NaN  4.0        2014  256   C   23
# 134                 University of Kentucky  4.0        2015  453   C   23
# 111                   University of Kansas  3.0        2014  149   C   24
# 30                                     NaN  5.0        2014   86   C   24
# 171               University of Louisville  4.0        2015  199   C   25
# 132                                    NaN  5.0        2014  359   C   24
# 56                      Gonzaga University  3.0        2016  410   C   22
# 188         Bowling Green State University  4.0        2015  225   C   25
# 123                 University of Kentucky  5.0        2014  393   C   24
# 112                 Wake Forest University  2.0        2017  104  PF   21
# 218                     Indiana University  2.0        2017   76   C   21
# 168                                    NaN  1.0        2018  403   C   20
# 44                   University of Arizona  1.0        2018   24   C   20
# 239                                    NaN  3.0        2015  212   C   24
# 12              Louisiana State University  2.0        2016  422  PG   22
# 93                         Duke University  4.0        2015  364   C   23
# 87                                     NaN  3.0        2016  502   C   21
# 62                     Stanford University  5.0        2014  387   C   27
# 152                                    NaN  1.0        2018  136  SG   19
# 86                                     NaN  3.0        2016  502   C   21
# 32                   Ohio State University  4.0        2015  409  PG   22
# 173          University of Texas at Austin  4.0        2015  458   C   22
# 102          University of Texas at Austin  2.0        2017   11   C   20
# 53                  University of Kentucky  4.0        2015   58  SG   22
# 95                      University of Utah  3.0        2016  383   C   23
# 182            New Mexico State University  3.0        2016  421  PF   24
# 241  University of California, Los Angeles  5.0        2014  279  SG   23
# 238                 University of Kentucky  4.0        2015   94   C   25
# 42                  University of Kentucky  2.0        2017  165  PG   21
# 13                  University of Arkansas  4.0        2015  386  PF   23
# ..                                     ...  ...         ...  ...  ..  ...
# 96                    Villanova University  1.0        2018   75  PG   22
# 210          Southern Methodist University  2.0        2017   73  SG   23
# 79                  University of Kentucky  1.0        2018  132  SG   20
# 153                        Duke University  2.0        2017  265  SG   22
# 33                  University of Michigan  2.0        2017  492  PF   22
# 23                 Murray State University  4.0        2015  377  PG   24
# 59                    Creighton University  5.0        2014  317  SF   27
# 31                   University of Alabama  1.0        2018  418  PG   20
# 174                 University of Michigan  5.0        2014  434  SG   25
# 125           University of North Carolina  2.0        2017  244  SF   23
# 128                 University of Maryland  NaN        2018  244  SF   23
# 129                 University of Maryland  NaN        2018  244  SF   23
# 126           University of North Carolina  2.0        2017  244  SF   23
# 107               University of Notre Dame  4.0        2015  187  PG   26
# 208                  University of Arizona  4.0        2015  253  SF   22
# 139                 University of Maryland  1.0        2018  230  SG   20
# 118                   Villanova University  2.0        2017  206  SG   23
# 159                                    NaN  4.0        2015  213  SF   23
# 43       University of Southern California  1.0        2018  324  PG   20
# 207                  University of Arizona  4.0        2015  253  SF   22
# 180                     Indiana University  2.0        2017   20  SF   21
# 237                Kansas State University  2.0        2017  239  SF   24
# 27                  Boise State University  1.0        2018  231  SF   22
# 68                         Duke University  1.0        2017  241  PG   20
# 120        Georgia Institute of Technology  1.0        2018  366  SG   20
# 140                 University of Kentucky  1.0        2018  270  PF   19
# 66                                     NaN  1.0        2018  365  PG   21
# 216                                    NaN  2.0        2017  160  SG   20
# 18                     University of Miami  1.0        2018   70  SG   22
# 71                                     NaN  2.0        2017  357  PG   20
#
#       Tm  ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 177  DEN  ...  15.6  27.7  5.9  2.8  8.7  0.236   6.3   3.4  9.7   5.2
# 134  MIN  ...  13.4  27.4  5.3  2.7  8.0  0.203   4.5   2.4  6.9   4.2
# 111  PHI  ...  13.5  33.2  4.1  3.1  7.3  0.192   1.4   1.9  3.3   2.4
# 30   HOU  ...  10.1  19.3  5.0  1.5  6.4  0.215   1.5   1.0  2.6   1.6
# 171  LAC  ...  10.2  22.4  4.6  1.9  6.5  0.200   2.8   1.8  4.6   2.6
# 132  POR  ...  14.4  24.4  3.1  2.6  5.7  0.180   1.2   3.8  5.1   2.7
# 56   IND  ...  16.7  23.0  3.5  2.7  6.3  0.217   1.8   2.4  4.1   2.2
# 188  PHO  ...  10.9  17.6  2.6  0.8  3.4  0.186   0.6   1.7  2.2   0.9
# 123  NOP  ...  13.8  26.7  3.5  1.4  4.9  0.153   1.9  -0.2  1.8   1.5
# 112  ATL  ...  12.2  23.5  3.4  0.6  4.0  0.152   2.9  -1.6  1.2   1.0
# 218  WAS  ...   9.0  17.1  2.8  0.8  3.6  0.190   1.2   0.1  1.3   0.8
# 168  NYK  ...   9.5  11.9  2.1  1.1  3.1  0.199   0.8   5.3  6.1   1.5
# 44   PHO  ...  11.8  21.4  3.3  1.2  4.6  0.134   0.3   0.4  0.8   1.1
# 239  CHO  ...  13.8  22.8  1.3  0.7  2.0  0.153  -0.1  -0.8 -0.8   0.2
# 12   PHI  ...  20.1  22.2  3.5  2.6  6.1  0.152   1.5   2.6  4.1   2.9
# 93   NOP  ...  11.0  19.8  1.2  0.5  1.8  0.149  -0.5  -0.7 -1.3   0.1
# 87   LAL  ...  12.9  20.5  1.2  0.6  1.8  0.170  -1.1   0.3 -0.8   0.2
# 62   DAL  ...  10.7  18.0  2.7  1.2  3.9  0.203   1.6   1.2  2.8   1.1
# 152  DAL  ...  14.7  29.1  2.2  2.2  4.3  0.118   2.9   0.9  3.8   2.6
# 86   TOT  ...  13.6  20.6  1.2  0.7  1.9  0.161  -1.6   0.2 -1.4   0.1
# 32   BRK  ...  13.5  30.7  1.9  1.6  3.4  0.094   3.4  -1.0  2.4   1.9
# 173  IND  ...  10.6  20.2  1.6  3.4  5.0  0.160  -1.2   5.0  3.8   2.2
# 102  BRK  ...  13.2  16.2  3.2  2.2  5.4  0.169  -0.4   3.0  2.6   1.8
# 53   PHO  ...  15.3  31.5  1.7  0.2  1.9  0.060   3.1  -3.0  0.1   0.8
# 95   SAS  ...  14.9  14.1  2.2  0.8  3.0  0.176   1.6   1.5  3.2   1.1
# 182  TOR  ...  12.3  19.9  4.2  2.5  6.6  0.174   1.9   1.6  3.5   2.5
# 241  CHI  ...  14.0  30.4  1.2  1.0  2.2  0.061   1.4  -1.6 -0.2   0.8
# 238  SAC  ...   9.5  18.8  2.5  2.2  4.7  0.140  -0.2   2.3  2.1   1.6
# 42   SAC  ...  16.2  24.6  2.0  1.7  3.8  0.103   0.9   0.0  0.9   1.3
# 13   TOT  ...   9.3  26.1  0.5  0.6  1.0  0.076  -0.5  -1.9 -2.4  -0.1
# ..   ...  ...   ...   ...  ...  ...  ...    ...   ...   ...  ...   ...
# 96   DAL  ...  12.6  18.0  0.3  0.7  1.0  0.054  -2.4  -1.0 -3.4  -0.3
# 210  MIL  ...  12.3  14.2  0.5  1.1  1.6  0.104  -1.5   0.1 -1.4   0.1
# 79   OKC  ...  11.0  16.6  0.2  0.7  0.8  0.079  -4.0  -0.4 -4.4  -0.3
# 153  DET  ...   9.3  18.0  0.3  0.8  1.0  0.063  -1.8  -0.7 -2.5  -0.1
# 33   MIL  ...  10.4  13.8  0.2  1.0  1.1  0.103  -2.5   1.7 -0.8   0.2
# 23   CHI  ...  16.0  17.5 -0.1  0.3  0.2  0.017  -2.8  -1.4 -4.2  -0.3
# 59   IND  ...   8.7  15.3  1.1  0.9  2.0  0.102  -0.3  -1.8 -2.1   0.0
# 31   CLE  ...  12.6  25.3 -1.2 -0.3 -1.5 -0.040  -2.9  -3.5 -6.4  -2.0
# 174  TOT  ...  14.0  17.8  0.2  0.4  0.6  0.043  -1.3  -1.8 -3.1  -0.2
# 125  TOT  ...   6.5  13.2  1.0  0.7  1.7  0.074  -0.9  -0.8 -1.6   0.1
# 128  TOT  ...   6.5  13.2  1.0  0.7  1.7  0.074  -0.9  -0.8 -1.6   0.1
# 129  SAC  ...   6.5  12.9  1.0  0.7  1.7  0.074  -0.8  -0.7 -1.5   0.1
# 126  SAC  ...   6.5  12.9  1.0  0.7  1.7  0.074  -0.8  -0.7 -1.5   0.1
# 107  ORL  ...  18.7  13.3  0.2  0.9  1.1  0.065  -2.4   0.0 -2.4  -0.1
# 208  DET  ...  12.9  19.0 -0.7  1.4  0.7  0.036  -3.1   1.1 -2.0   0.0
# 139  ATL  ...  15.7  15.2  0.4  0.5  0.9  0.030  -1.1  -1.0 -2.1   0.0
# 118  LAL  ...  10.9  14.1  0.2  1.6  1.9  0.063  -1.5   1.1 -0.4   0.6
# 159  NYK  ...  12.6  20.5 -1.1  0.8 -0.3 -0.014  -4.1  -0.6 -4.8  -0.6
# 43   PHO  ...  21.5  16.3 -0.8  0.6 -0.2 -0.012  -3.7   1.2 -2.4  -0.1
# 207  TOT  ...  12.7  18.9 -0.8  1.5  0.6  0.030  -3.3   1.0 -2.3  -0.1
# 180  TOR  ...   9.5  15.7  0.2  1.1  1.3  0.063  -1.4  -0.2 -1.6   0.1
# 237  ORL  ...  12.2  14.0  0.2  0.8  1.1  0.066  -3.6   0.6 -3.0  -0.2
# 27   CHI  ...  10.0  12.3  0.0  0.6  0.6  0.033  -4.0  -0.2 -4.2  -0.5
# 68   NOP  ...   9.9  17.6  0.0  0.2  0.2  0.016  -2.3  -2.9 -5.2  -0.5
# 120  MIN  ...  11.1  16.7 -0.5  0.9  0.4  0.016  -2.8  -0.1 -2.9  -0.2
# 140  NYK  ...  10.1  22.3 -1.6  0.5 -1.1 -0.038  -3.8  -2.6 -6.3  -1.6
# 66   PHO  ...  18.2  17.1 -0.7  0.2 -0.6 -0.036  -4.1  -2.2 -6.2  -0.8
# 216  OKC  ...   8.1  10.8  0.8  1.1  2.0  0.079  -1.4  -0.5 -1.9   0.0
# 18   DET  ...  12.2  12.6 -0.3  1.0  0.7  0.035  -4.1   1.5 -2.6  -0.2
# 71   NYK  ...  15.8  16.6 -1.2  0.4 -0.8 -0.043  -4.2  -1.0 -5.2  -0.7
#
# [141 rows x 32 columns]

# %% [markdown]
# ## import seaborn as sns
# import matplotlib.pyplot as plt
# %matplotlib inline
#
#
# dims = (16, 9)
# fig, ax = plt.subplots(figsize=dims)
#
# team = 'DEN'
# sub = merged_2019[merged_2019.MP > 500]
# sub['is_team'] = sub['Tm'].apply(lambda x: x == team)
#
# sns.scatterplot(ax=ax, data=sub, x='Pk', y='VORP', hue='is_team', legend=False)
