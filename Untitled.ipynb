# %%
import pandas as pd

# %%
csv = pd.read_csv('/Users/jimmyzhang/Personal/good_gov.csv', skiprows=skip, thousands=',')
csv.head()
# Out:
#      indicator ISO Country code  population  surface area (Km2)  Unnamed: 4  \
# 0  Afghanistan              AFG    36000000              652230         NaN
# 1      Albania              ALB     2900000               27398         NaN
# 2      Algeria              DZA    41000000             2381740         NaN
# 3      Andorra              AND       77000                 468         NaN
# 4       Angola              AGO    30000000             1246700         NaN
#
#   GINI index happy planet index human development index  \
# 0          -               20.2                   0.498
# 1       29.0               36.8                   0.785
# 2       35.3               33.3                   0.754
# 3          -                  -                   0.858
# 4       42.7                  -                   0.581
#
#   world happiness report score  \
# 0                         2.66
# 1                         4.64
# 2                         5.25
# 3                            -
# 4                            -
#
#   sustainable economic development assessment (SEDA)           ...             \
# 0                                                  -           ...
# 1                                              53.10           ...
# 2                                              45.80           ...
# 3                                                  -           ...
# 4                                              28.40           ...
#
#    regulatory quality rule of law control of corruption  \
# 0                -1.3      -1.570                 -1.52
# 1                 0.2      -0.400                 -0.42
# 2                -1.2      -0.860                 -0.61
# 3                 1.2       1.600                  1.24
# 4                -1.0      -1.100                 -1.41
#
#   judicial effectiveness score government integrity score  \
# 0                        28.20                      26.20
# 1                        25.40                      39.90
# 2                        35.20                      29.00
# 3                            -                          -
# 4                        25.40                      18.90
#
#   property rights score tax burden score overall economic freedom score  \
# 0                 17.90            91.80                          51.30
# 1                 54.10            85.10                          64.50
# 2                 27.80            74.00                          44.70
# 3                     -                -                              -
# 4                 36.00            82.40                          48.60
#
#   financial freedom score women MPs (% of all MPs)
# 0                   10.00                     27.7
# 1                   70.00                     27.9
# 2                   30.00                     25.8
# 3                       -                     32.1
# 4                   40.00                     38.2
#
# [5 rows x 37 columns]

# %%
def process(data):
    for c in data.columns:
        if 'Unnamed' in c:
            data.drop(columns=[c], inplace=True)
    data = data.set_index('indicator')
    for c in data.columns:
        if c == 'GDP per capita (PPP)':
            data[c] = data[c].str.replace(',', '')
        
        if c != 'ISO Country code':
            
            data[c] = pd.to_numeric(data[c].replace('-', np.nan), errors='downcast')
    
    return data

# %%
csv = pd.read_csv('/Users/jimmyzhang/Personal/good_gov.csv', skiprows=skip, thousands=',')

# %%
csv = process(csv)

# %%
import scipy

# %%
cols = [c for c in csv.columns[22:]]

x = csv[cols].values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df = pd.DataFrame(x_scaled, columns=cols)




splot = pd.melt(df)

# %%
import matplotlib.pyplot as plt
a4_dims = (25, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sns.stripplot(ax=ax, x='variable', y='value', data=splot, jitter=0)

# %%
subcsv = csv[csv.columns[20:]]
sns.heatmap(subcsv.corr(), 
            xticklabels=subcsv.columns.values,
            yticklabels=subcsv.columns.values)

# %%
csv.columns
# Out:
# Index(['ISO Country code', 'population', 'surface area (Km2)', 'GINI index',
#        'happy planet index', 'human development index',
#        'world happiness report score',
#        'sustainable economic development assessment (SEDA)',
#        'GDP \n(billions PPP)', 'GDP per capita (PPP)',
#        'GDP growth\n(annual %)', 'health expenditure \n% of GDP',
#        'health expenditure \nper person', 'education expenditure\n% of GDP',
#        'education expenditure \nper person ', 'school life expectancy (YEARS)',
#        'unemployment (%)', 'government spending score',
#        'government expenditure (% of GDP)', 'political rights score ',
#        'civil liberties score ', 'political stability & absence of violence',
#        'government effectiveness', 'regulatory quality', 'rule of law',
#        'control of corruption', 'judicial effectiveness score',
#        'government integrity score', 'property rights score',
#        'tax burden score', 'overall economic freedom score',
#        'financial freedom score', 'women MPs (% of all MPs)'],
#       dtype='object')

# %%
for c in csv.columns[1:]:
    csv.plot(kind='scatter', x='political stability & absence of violence', y=c)
# Out:
# /Users/jimmyzhang/.virtualenvs/jupyter/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
